# %%
import os
import sys
import pandas as pd

BASE_DIR = os.path.abspath(
    os.path.join(os.getcwd(), "..")
)

print("Project:", BASE_DIR)

TIKTOK_DIR = os.path.join(
    BASE_DIR,
    "ingestion",
    "tiktok"
)

RAW_DIR = os.path.join(
    BASE_DIR,
    "data",
    "raw",
    "tiktok"
)

print("TikTok:", TIKTOK_DIR)
print("Raw:", RAW_DIR)

# %%
keyword_file = os.path.join(
    TIKTOK_DIR,
    "keyword.csv"
)

df_keyword = pd.read_csv(
    keyword_file,
    encoding="utf-8-sig"
)

display(df_keyword)

# %%
print("Số dòng:", len(df_tiktok))

print(
    "Số video unique:",
    df_tiktok["video_url"].nunique()
)

print(
    "Missing video_url:",
    df_tiktok["video_url"].isna().sum()
)

print(
    "Missing province:",
    df_tiktok["province"].isna().sum()
)

print(
    "Missing category:",
    df_tiktok["category"].isna().sum()
)

print(
    "Duplicate:",
    df_tiktok.duplicated(
        subset=["video_url"]
    ).sum()
)
